# %%
import numpy as np # linear algebra
import pandas as pd 
import matplotlib.pyplot as plt

# %% [markdown]
# ### Load Data

# %%
#data = pd.read_csv("https://covid.ourworldindata.org/data/owid-covid-data.csv")
#data.to_csv('Coronavirus_cases_daily_update.csv', encoding='utf-8', index=False)
data =  pd.read_csv('Coronavirus_cases_daily_update.csv', sep = ',')
data.head()
# Out:
#   iso_code continent     location        date  total_cases  new_cases  \
# 0      AFG      Asia  Afghanistan  2020-01-05          0.0        0.0
# 1      AFG      Asia  Afghanistan  2020-01-06          0.0        0.0
# 2      AFG      Asia  Afghanistan  2020-01-07          0.0        0.0
# 3      AFG      Asia  Afghanistan  2020-01-08          0.0        0.0
# 4      AFG      Asia  Afghanistan  2020-01-09          0.0        0.0
#
#    new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 0                 NaN           0.0         0.0                  NaN  ...
# 1                 NaN           0.0         0.0                  NaN  ...
# 2                 NaN           0.0         0.0                  NaN  ...
# 3                 NaN           0.0         0.0                  NaN  ...
# 4                 NaN           0.0         0.0                  NaN  ...
#
#    male_smokers  handwashing_facilities  hospital_beds_per_thousand  \
# ...

# %%
data = data[['iso_code', 'total_cases']]
data.head()
# Out:
#   iso_code  total_cases
# 0      AFG          0.0
# 1      AFG          0.0
# 2      AFG          0.0
# 3      AFG          0.0
# 4      AFG          0.0

# %% [markdown]
# ### Data Preparation (Processing)

# %%
x = np.array(data['iso_code']).reshape(-1,1)
y = np.array(data['total_cases']).reshape(-1,1)

print(data.isnull().sum())
data =  data.dropna() #drop null values

print(data.isnull().sum())

plt.plot(y)
plt.show()
# Out:
# iso_code           0
# total_cases    17631
# dtype: int64
# iso_code       0
# total_cases    0
# dtype: int64

# %%
from sklearn.preprocessing import PolynomialFeatures

polyFeat = PolynomialFeatures(degree=2) 
x = polyFeat.fit_transform(x)
print(x)

# %% [markdown]
# ### Training

# %%
from sklearn import linear_model

model = linear_model.LinearRegression()
model.fit(x,y)

accuracy = model.score(x,y)
print("accurary: ", round(accuracy, 2))

# %%
y0 = model.predict(x)
plt.plot(y0, '--b')
plt.show()
